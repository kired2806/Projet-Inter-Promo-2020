# %% [markdown]
# Created on Monday 4 January 2021
#
# **Group 5 - Classification**
# **Example of a notebook according to the quality charter v0** (Title)
#
# @authors : Alice Airault

# %% [markdown]
# Small description of the Notebook

# %% [markdown]
# # Import

# %% [markdown]
# Note: Import only the modules used in the notebook.

# %%
import os
import sys
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# # Creation of the link between the drive and the notebook

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Part

# %% [markdown]
# Short description of the part

# %%
C: int = 0
Constant: str = 'ok'
variable: int = 1 + 2
text: str = 'hello'
my_text: str = str(variable)
my_list: list = [1, 2, 3]
my_dict: dict = {'key1': 'value1', 'key2': 'value2'}

# %%
def my_function(nb: int, to_add: float = 3.5) -> float:
    """Documentation
    Parameters:
        nb: description
        to_add: description

    Out (if exists):
        new_nb: description

    References:
        1. http://myfirstreference.com
        2. http://mysecondreference.com
    """

    # Step 1: calculate the new number
    for v in vals:
        # comment
        new_nb = nb + my_float  # or comment

    return new_nb
