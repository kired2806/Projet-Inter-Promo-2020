# %%
# %load_ext google.colab.data_table

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os.path, time
print("created: %s" % time.ctime(os.path.getctime("/content/drive/MyDrive/G5 Inter-Promo 2021/Données/Input/Data.json")))
# Out:
# created: Sun Jan  3 23:42:08 2021

# %%
# !pip install transformers

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_json("/content/drive/MyDrive/G5 Inter-Promo 2021/Données/Input/Data.json")

# %%
df=pd.DataFrame({'art_id':data['art_id'],
                'art_title':data['art_title'],
                'art_tag':data['art_tag']})

# %%
## clean tag
clean_tags=train['art_tag']
for i,row in enumerate(clean_tags):
  try :
    clean_tags[i]=row.replace("#","").replace('[','').replace(']','')
  except:
    clean_tags[i]=row.replace("#","")
train['art_tag']=clean_tags
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
## list tags
list_tags=[]
for tags in train['art_tag']:
  if str(tags) == "Not Found" or pd.isnull(tags):
    list_tags.append([])
    print(list_tags)
    pass
  elif type(tags)==str:
    try:
      list_tags.append(eval(tags))
    except:
      list_tags.append([tags])
print(len(list_tags))
print(len(train['art_tag']))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...

# %%
data_train = train.copy()
data_train = pd.concat([pd.Series(list_tags, name="tag"),data_train], axis=1)
data_train.head(100)
# Out:
#                                                   tag  ...                      art_tag
# 0            (Evénement, Relation citoyens, Internet)  ...                          NaN
# 1            (Evénement, Relation citoyens, Internet)  ...                          NaN
# 2      (Evénement, Gestion eau, Mutualisation, Cloud)  ...                          NaN
# 3   (Innover, Relation citoyens, Collaboratif, Dém...  ...                          NaN
# 4                   (Comptabilité, Dématérialisation)  ...                          NaN
# ..                                                ...  ...                          ...
# 95                              Collectivités locales  ...      'Politique de la ville'
# 96                              Collectivités locales  ...  'Aménagement du territoire'
# 97                              Hébergement d'urgence  ...      'Politique de la ville'
# 98                            Acteurs des territoires  ...                'Copropriété'
# ...

# %%
data = pd.read_json("/content/drive/MyDrive/G5 Inter-Promo 2021/Données/Input/Data.json")

# %%
dataClean=pd.read_json("/content/drive/MyDrive/G5 Inter-Promo 2021/Données/Input/df_final_clean.json")
titles=["vide"]*7533
tags=[[]]*7533
index=0
for i in dataClean['art_id']:
  titles[index]=data.loc[data['art_id']==i]['art_title'].values[0]
  test_list=data.loc[data['art_id']==i]['art_tag'].values[0]
  if test_list==None:
    tags[index]=[]
  elif test_list[0]=='[':
      tags[index]=eval(test_list.lower())
  else:
    if "Not Found"==test_list:
      tags[index]=[]
    else:
      tags[index]=[test_list.lower()]
  index=index+1
for i in range(len(tags)):
  if tags[i]==['']:
    tags[i]=[]
  for j in range(len(tags[i])):
    if tags[i][j][0]=='#':
      tags[i][j]=tags[i][j][1:]
dataClean['titles']=titles
dataClean['tags_Name']=tags

# %%
data2=dataClean.sample(100)
data2.head(1)
# Out:
#       art_id  ...                                         tags_Name
# 4153    4153  ...  [Finance & Fiscalité,  TPE & Auto-entrepreneurs]
#
# [1 rows x 5 columns]

# %%
for tag in data2['titles'][:1]:
  print(tag)
# Out:
# Dématérialisation, les processus et métiers dématérialisés

# %%
dict_classes = {
            'international': 0,
            'france': 1,
            'economie': 2,
            'science': 3,
            'transport': 4,
            'sports': 5,
            'sante': 6,
            'environement': 7,
            'education': 8,
            'securite': 9,
            'entreprise': 10,
            'legislation': 11
    }

# %%
raw_tags=data["art_tag"].values
tags=[]
set_of_tags = set()
for tag in raw_tags:
  if tag!=None:
    if tag[0]=='[':
      list_of_tags=eval(tag)
      for tag_in_list in list_of_tags:
        tags.append(tag_in_list)
for tag in tags:
  if tag!='' and tag!=None:
    tag=tag.lower()
    if tag[0]=='#':
      tag=tag[1:]
    set_of_tags.add(tag)
print(len(set_of_tags))
set_of_tags=sorted(set_of_tags)
# Out:
# 1153

# %%
import itertools
class my_list(list):
    def add(self, i_tags:list ,set_of_tags: list):
        for arg in i_tags:
            self.append(set_of_tags[arg])



international = my_list()
france = my_list()
economie = my_list()
science = my_list()
transport =my_list()
sports =my_list()
sante = my_list()
environement =my_list()
education = my_list()
securite = my_list()
entreprise = my_list()
legislation = my_list()

international_tags = [85,254,266,773,966,249,31,36,103,126,147,179,505,513,521,536,540,591,812,815,856,898,420,422,442,451,478,485,754,769,772,787,307,363,373,376,628,650,655,1006,1023,965,973,977]
france_tags =[48,49,50,51,52,53,287,419,476,569,603,810,821,115,568,811,770,604,607,620,621,627,658,664,677]
economie_tags =[985,980,979,118,37,109,114,118,137,242,629,226,229,300,0,14,23,82,101,102,119,120,145,151,178,186,519,583,853,854,404,405,406,407,408,409,723,725,779,783,784,747,300,301,302,303,349,350,364,365,382,384,602,605,610,639,659,660,661,662,695,1016,1028,1029,1030,1031,910,911,979,980,985]
science_tags = [7,8,9,12,686,687,734,834,941,47,117,257,258,44,45,47,59,61,67,117,125,128,129,134,207,215,216,244,258,270,362,421,469,475,507,508,520,541,543,563,564,219,233,235,236,237,238,240,245,246,247,248,255,256,257,278,279,283,285,290,291,292,295,296,297,875,54,55,56,60,77,88,89,104,105,107,108,113,160,161,166,167,180,197,196,198,506,509,514,515,527,539,590,814,816,818,819,820,836,837,849,860,862,863,864,865,866,867,868,867,868,869,870,871,872,873,874,875,894,400,403,418,441,454,459,461,465,470,473,480,481,487,488,490,494,497,499,498,759,761,762,790,791,792,798,799,1014,313,314,315,323,324,325,326,331,356,357,398,626,633,634,635,636,637,640,641,642,688,1000,1001,1002,1007,1015,1017,1018,1022,1025,1035,1036,1040,1041,1042,1044,943,202,203,900,907,908,909,913,914,915,917,919,924,929,931,936,937,939,940,957,958,959,960,961,962,963,964,981,983,988,993,997,999]
transport_tags = [95,94,95,100,535,223,366,1003,1004,1009,1010,1011,1012,934,935,944,945,946,947,948,949,950,956]
sports_tags = [234,281,526,887,413,623,676]
sante_tags= [259,112,222,225,243,253,414,631,750,740,756,830,217,259,972,80,570,576,828,829,831,832,882,457,458,472,351,354,360,369,611,612,613,615,616,663,671,685]
environement_tags = [18,32,33,34,43,132,133,175,176,177,550,552,571,588,275,276,293,298,299,4,106,110,111,135,136,139,152,153,156,158,159,161,165,182,183,181,182,183,501,522,558,567,589,817,858,878,423,427,434,455,456,466,467,468,479,489,716,717,737,739,743,766,767,774,776,778,796,800,348,622,674,1008,1024,1027,1033,1034,1045,942,932,969,970,971,974,975,986,987,989,990,991,992,994,995]
education_tags = [250,967,968,62,838,401,416,452,462,492,493,722,735,751,304,319,332,333,334,335,336,337,361,370,374,375,630,699,1026,1037,1047,1048]
securite_tags = [86,282,578,584,585,210,903,904,905,906,996,65,66,518,592,841,897,430,471,483,724,742,745,788,654]
entreprise_tags = [15,24,29,99,121,122,144,148,150,154,163,218,230,241,389,424,425,432,445,447,486,495,544,545,573,579,647,656,680,736,738,757,760,795,786,793,802,807,885,886,976,209,224,228,901,916,918,923,933,951,952,982,5,57,58,192,537,549,582,823,824,850,876,880,888,889,890,895,429,433,436,437,446,460,500,718,729,730,731,732,733,755,764,765,768,771,789,794,306,320,321,322,329,330,338,339,340,341,342,343,344,345,346,347,355,358,378,391,618,624,632,643,644,645,649,657,668,669,675,678,689,690,698,1019]
legislation_tags = [46,98,155,157,271,273,280,368,380,410,415,463,502,503,504,546,547,548,560,565,577,200,204,205,260,261,262,263,264,265,26,267,268,269,274,284,839,1,2,97,162,529,530,531,532,533,534,559,594,804,805,806,813,826,855,857,411,412,435,439,440,443,482,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,719,721,726,741,746,748,749,797,411,412,435,439,440,443,482,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,719,721,726,741,746,748,749,797,305,308,309,310,311,312,317,318,371,606,646,648,651,653,665,666,670,681,682,691,692,693,694,696,1005,1038,1039,1043]

## All Tags
liste_all_tags = list(itertools.chain(international_tags,france_tags,economie_tags,science_tags,transport_tags,sports_tags,sante_tags,environement_tags,education_tags,securite_tags,entreprise_tags,legislation_tags))
## All labels
international.add(international_tags,list(set_of_tags))
france.add(france_tags,list(set_of_tags))
economie.add(economie_tags,list(set_of_tags))
science.add(science_tags,list(set_of_tags))
transport.add(transport_tags,list(set_of_tags))
sports.add(sports_tags,list(set_of_tags))
sante.add(sante_tags,list(set_of_tags))
environement.add(environement_tags,list(set_of_tags))
education.add(education_tags,list(set_of_tags))
securite.add(securite_tags,list(set_of_tags))
entreprise.add(entreprise_tags,list(set_of_tags))
legislation.add(legislation_tags,list(set_of_tags))
## Left Tags
set_of_tags_left=set_of_tags.copy()
for i in list(set(liste_all_tags)):
  set_of_tags_left.remove(set_of_tags[i])
print(len(set_of_tags_left))

for i in set_of_tags_left:
  print(set_of_tags.index(i) ,i)

# %%
def get_labels(tags,international,france,economie,science,transport,sports,sante,environement,education,securite,entreprise,legislation):
  labels={}
  for tag in tags:
    if tag in international:
      if "international" in labels.keys():
        labels['international']+=1
      else:
         labels['international']=1
    if tag in france:
      if "france" in labels.keys():
          labels['france']+=1
      else:
          labels['france']=1

    if tag in economie:
      if "economie" in labels.keys():
        labels['economie']+=1
      else:
        labels['economie']=1
      
    if tag in science:
      if "science" in labels.keys():
        labels['science']+=1
      else:
        labels['science']=1
      

    if tag in transport:
      if "transport" in labels.keys():
        labels['transport']+=1
      else:
        labels['transport']=1


    if tag in sports:
      if "sports" in labels.keys():

        labels['sports']+=1
      else:
        labels['sports']=1
        

    if tag in sante:
      if "sante" in labels.keys():
        labels['sante']+=1
      else:
        labels['sante']=1

        
    if tag in environement:
      if str(environement) in labels.keys():
        labels['environement']+=1
      else:
        labels['environement']=1
      
    if tag in education:
      if "education" in labels.keys():
        labels['education']+=1
      else:
        labels['education']=1

    if tag in securite:
      if "securite" in labels.keys():
        labels['securite']+=1
      else:
        labels['securite']=1
      
    if tag in entreprise:
        if 'entreprise' in labels.keys():
          labels['entreprise']+=1
        else:
          labels['entreprise']=1


    if tag in legislation:
        if "legislation" in labels.keys():
          labels['legislation']+=1
        else:
          labels['legislation']=1

  return labels

# %%
print(sports)
# Out:
# ['cyclistes', 'défense', 'jo paris 2024', 'sport', 'fitness', 'nautisme', 'pavic']

# %%
tags=['cyclistes','economie','vie économique','politique économique']
get_labels(tags,international,france,economie,science,transport,sports,sante,environement,education,securite,entreprise,legislation)
# Out:
# {}

# %%
def find(tag,international,france,economie,science,transport,sports,sante,environement,education,securite,entreprise,legislation):
  return (tag in (international or france or economie or science or transport or sports or sante or environement or education or securite or entreprise or legislation))

# %%
print(find('Politique économique',international,france,economie,science,transport,sports,sante,environement,education,securite,entreprise,legislation))
# Out:
# False

# %%
dataClean.sample(10)

# %%
def calcul_max_similiraties(title,labels):
  similarityMax=0
  tag_max=''
  word1 = wordnet.synsets(title)
  if len(word1) != 0:
      word1 = word1[0]
      for word2 in labels:
        word=word2
        if len(word2)!= 0:
          word2 = wordnet.synsets(word2)[0]
          similarity=word1.path_similarity(word2)
          if (similarity>similarityMax):
            similarityMax=similarity
            tag_max=word
  return (tag_max)

# %%
dataClean['labels']='a'

# %%
dataClean['labels']=''
labels_column=dataClean['labels']
for i,row in dataClean.iterrows():
  if len(tags)>0:
    labels_column[i]=get_labels(row['tags_Name'],international,france,economie,science,transport,sports,sante,environement,education,securite,entreprise,legislation)
dataClean['labels']=labels_column
print(dataClean.sample(15))
# Out:
#        art_id  ... labels
# 1538     1538  ...
# 11906   11906  ...
# 7620     7620  ...
# 2573     2573  ...
# 6950     6950  ...
# 7399     7399  ...
# 11978   11978  ...
# 3454     3454  ...
# 4099     4099  ...
# 9217     9217  ...
# 8143     8143  ...
# 1417     1417  ...
# 9439     9439  ...
# 11792   11792  ...
# 2792     2792  ...
#
# [15 rows x 6 columns]
