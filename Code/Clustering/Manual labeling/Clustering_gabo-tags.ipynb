# %%
# %matplotlib inline
import re
import string
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext google.colab.data_table
data = pd.read_json("/content/drive/MyDrive/G5 Inter-Promo 2021/Données/Input/Data.json")
print(len(data))
data.head(3)
# Out:
# 12261
#    art_id                                        art_content  ... art_auth art_tag
# 0       0                                                     ...     None    None
# 1       1  La FNCDG et l’ANDCDG ont publié en septembre l...  ...     None    None
# 2       2  Malgré la levée des mesures de confinement le ...  ...     None    None
#
# [3 rows x 13 columns]

# %%
data['art_tag'].describe()
# Out:
# count         10625
# unique         1732
# top       Not Found
# freq           1055
# Name: art_tag, dtype: object

# %%
raw_tags=data["art_tag"].values
tags=[]
set_of_tags = set()
for tag in raw_tags:
  if tag!=None:
    if tag[0]=='[':
      list_of_tags=eval(tag)
      for tag_in_list in list_of_tags:
        tags.append(tag_in_list)
for tag in tags:
  if tag!='' and tag!=None:
    tag=tag.lower()
    if tag[0]=='#':
      tag=tag[1:]
    set_of_tags.add(tag)
print(len(set_of_tags))
for i in set_of_tags:
  print(i)
# Out:
# 1051
# pandémie
# coter club - coter numérique
# constitution européenne
# impôt
# religion
# laval virtual
# mobiles
# tri
# droit des sociétés
# développement
# digitalisation
# protection des données
# français à l'étranger
# laïcité
# régions du monde
# services.
# nationalité francaise
# bâtiment et travaux publics
# liberté
# commune nouvelle
# franceconnect
# entreprise de services
# ia
# electronic
# entrepreneurs
#  tpe & auto-entrepreneurs
# urbanisation
# territoires numériques
# dette publique
# recherche développement
# licenciement
# réseaux bas débit
# propreté
# rse
# déconcentration
# droit civil
# assistant digital
# bureau
# nature
# google
# éclairage
# consommation énergétique
#  paie & ressources humaines
# médecin
# angers frenchtech
# parlement
# violence
# angers loire développement
# profession médicale
# communauté
# ville intelligente.
# innovation.
# collectivité
# pouvoirs
# french tech
# mobilités
# electricité
# débat
# consommation d'énergie
# ...

# %%
data['art_tag'].fillna("",inplace=True)

vectorizer = TfidfVectorizer()
vocabulary = vectorizer.fit_transform(data['art_tag'])
print(vectorizer.vocabulary_)
# Out:
# {'relations': 744, 'citoyennes': 148, 'cloud': 160, 'horizon': 443, 'télétravail': 899, 'gestion': 412, 'rh': 758, 'dématérialisation': 280, 'budget': 111, 'transformation': 882, 'numérique': 631, 'sécurité': 852, 'collaboratif': 164, 'organisation': 646, 'grc': 421, 'relation': 743, 'citoyens': 150, 'communication': 179, 'smart': 819, 'city': 151, 'elections': 297, 'finances': 380, 'services': 812, 'en': 308, 'ligne': 530, 'conseil': 201, 'municipal': 594, 'anti': 45, 'virus': 936, 'sauvegarde': 799, 'rgpd': 757, 'internet': 491, 'comptabilité': 181, 'evénement': 351, 'elus': 304, 'techniques': 860, 'environnement': 323, 'la': 513, 'une': 902, 'paie': 654, 'décisionnel': 276, 'messagerie': 571, 'accompagnement': 11, 'administration': 21, 'eau': 290, 'mutualisation': 597, 'innover': 477, 'intercommunalité': 487, 'app': 47, 'mobile': 577, 'mobilité': 580, 'aménagement': 39, 'du': 267, 'territoire': 867, 'acteurs': 17, 'des': 240, 'territoires': 868, 'action': 18, 'logement': 539, 'per
# ...

# %%
class my_list(list):
    def add(self, *args):
        for arg in args:
            self.append(arg)


            
international = my_list()
france = my_list()
economie = my_list()
numerique = my_list()
transport = my_list()
sports = my_list()
sante = my_list()
environement = my_list()
education = my_list()
securite = my_list()
entreprise = my_list()
legislation = my_list()

# %%
from itertools import islice
set_of_tags=sorted(set_of_tags)
for i, val in enumerate(islice(set_of_tags, 499, 501)):
  print(i+499, val)
list_of_tags=list(set_of_tags)
international = [420,422,442,451,478,485]
france = []
economie = [404,405,406,407,408,409]
science = [400,403,418,441,454,459,461,465,470,473,474,480,481,487,488,490,494,497,499,498]
transport = []
sports = []
sante = [413,457,458,472]
environement = [423,427,434,455,456,466,467,468,479,489]
education = [401,416,452,462,464,492,493]
securite=[430,471,483]
entreprise = [429,433,436,437,446,460,500]
legislation = [411,412,435,439,440,443,482]
list_wtf=[402,410,414,415,417,419,421,424,425,426,428,431,432,438,444,445,447,448,449,450,463,469,475,476,477,484,486,491,495,496,453]

#geolocalisation==453 gelolocalisation
#innovation 497=innovation. 498
# Out:
# 499 innover
# 500 insertion professionnelle

# %%
for i, val in enumerate(islice(set_of_tags, 797, 801)):
  print(i+797, val)
international = international + [754,769,772,787]
france =france + [747,770]
economie =economie + [723,725,727,779,783,784,]
science = science+ [759,761,762,790,791,792,798,799]
transport = transport+ []
sports =sports + []
sante =sante + []
environement =environement + [716,717,737,739,743,766,767,774,776,778,796,800]
education =education + [722,735,751]
securite=securite+[724,742,744,745,785,788]
entreprise =entreprise+ [718,729,730,731,732,733,755,764,765,768,771,789,794]
legislation =legislation+ [700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,719,721,726,741,746,748,749,797]
list_wtf =list_wtf + [720,728,734,736,738,740,750,752,753,756,757,758,760,763,773,775,777,780,781,782,786,793,795]
#peut etre interessant d ajouter "Produits et services"
#peut etre interessant d ajouter "industrie"
#795 et 796 sont environement?
total=international+france+economie+science+transport+sports+sante+environement+education+securite+entreprise+legislation+list_wtf
# Out:
# 797 règlementation
# 798 réalité augmentée
# 799 réalité virtuelle
# 800 réchauffement
# True

# %%
international = [420,422,442,451,478,485,54,769,772,787]
france = [747,770]
economie = [404,405,406,407,408,409]+[723,725,727,779,783,784,]
science = [400,403,418,441,454,459,461,465,470,473,474,480,481,487,488,490,494,497,499,498]+ [759,761,762,790,791,792,798,799]
transport = []
sports = []
sante = [413,457,458,472]
environement = [423,427,434,455,456,466,467,468,479,489]+ [716,717,737,739,743,766,767,774,776,778,796,800]
education = [401,416,452,462,464,492,493]+ [722,735,751]
securite=[430,471,483]+[724,742,744,745,785,788]
entreprise = [429,433,436,437,446,460,500]+[718,729,730,731,732,733,755,764,765,768,771,789,794]
legislation = [411,412,435,439,440,443,482]+[700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,719,721,726,741,746,748,749,797]
list_wtf=[402,410,414,415,417,419,421,424,425,426,428,431,432,438,444,445,447,448,449,450,463,469,475,476,477,484,486,491,495,496,453]+ [720,728,734,736,738,740,750,752,753,756,757,758,760,763,773,775,777,780,781,782,786,793,795]

# %%
international.add(set_of_tags(172), set_of_tags(169))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-392ef5ea234c> in <module>()
# ----> 1 international.add(set_of_tags(172), set_of_tags(169))
#
# TypeError: 'set' object is not callable

# %%
dict_classes = {
            'international': 0,
            'france': 1,
            'economie': 2,
            'numerique': 3,
            'transport': 4,
            'sports': 5,
            'sante': 6,
            'environement': 7,
            'education': 8,
            'securite': 9,
            'entreprise': 10,
            'legislation': 11
            }

# %%
set_of_tags_copy = set_of_tags.copy()

for i in :
  set_of_tags_copy.remove(i)

# %%
df = pd.DataFrame({'art_id':data['art_id'],
                   'art_tag':data['art_tag']})
                            
df['art_tag'].isna().values.sum()
# Out:
# 1636

# %%
test_set = df[df['art_tag'].isnull()]
len(test_set)
# Out:
# 1636

# %%
train_set = df[df['art_tag'].notnull()]
len(train_set)
# Out:
# 10625

# %%
ytrain = train_set['labels']
len(ytrain)
# Out:
# 10625

# %%
xtrain = vectorizer.transform(train_set['art_tag'])
xtrain = train_set.drop(['labels'], axis=1)

test_set.fillna("",inplace=True)
xtest = vectorizer.transform(test_set['art_tag'])
xtest = test_set.drop(['labels'], axis=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
ytrain = ytrain.map(dict_classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-b69389b2de32> in <module>()
# ----> 1 ytrain = ytrain.map(dict_classes)
#       2 ytest = ytest.map(dict_classes)
#
# NameError: name 'ytrain' is not defined

# %% [markdown]
# tags collecté v1.0

# %%
            
international = my_list()
france = my_list()
economie = my_list()
numerique = my_list()
transport = my_list()
sports = my_list()
sante = my_list()
environement = my_list()
education = my_list()
securite = my_list()
entreprise = my_list()
legislation = my_list()

## Nour
international_tags = [31,36,103,126,147,179,505,513,521,536,540,591,812,815,856,898]
france_tags =[115,568,811]
economie_tags =[0,14,23,82,101,102,119,120,145,151,178,186,519,583,853,854]
science_tags = [875,54,55,56,60,77,88,89,104,105,107,108,113,160,161,166,167,180,197,196,198,506,509,514,515,527,539,590,814,816,818,819,820,836,837,849,860,862,863,864,865,866,867,868,867,868,869,870,871,872,873,874,875,894]
transport_tags = []
sports_tags = [526,887]
sante_tags= [80,570,576,828,829,831,832,882]
environement_tags = [4,106,110,111,135,136,139,152,153,156,158,159,161,165,182,183,181,182,183,501,522,558,567,589,817,858,878]
education_tags = [62,838]
securite_tags = [65,66,518,592,841,897]
entreprise_tags = [5,57,58,192,537,549,582,823,824,850,876,880,888,889,890,895]
legislation_tags = [839,1,2,97,162,529,530,531,532,533,534,559,594,804,805,806,813,826,855,857]
## Gabriel 
internationalG = [420,422,442,451,478,485]+ [754,769,772,787]
franceG = [770]
economieG = [404,405,406,407,408,409]+[723,725,779,783,784,747]
scienceG = [400,403,418,441,454,459,461,465,470,473,480,481,487,488,490,494,497,499,498]+ [759,761,762,790,791,792,798,799]
transportG = []
sportsG = [413]
santeG = [457,458,472]
environementG = [423,427,434,455,456,466,467,468,479,489]+ [716,717,737,739,743,766,767,774,776,778,796,800]
educationG = [401,416,452,462,492,493]+ [722,735,751]
securiteG=[430,471,483]+[724,742,745,788]
entrepriseG = [429,433,436,437,446,460,500]+[718,729,730,731,732,733,755,764,765,768,771,789,794]
legislationG = [411,412,435,439,440,443,482]+[700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,719,721,726,741,746,748,749,797]
## Jessica
international_tagsJ = [307,363,373,376,628,650,655,1006,1023]
france_tagsJ = [604,607,620,621,627,658,664,677]
economie_tagsJ = [300,301,302,303,349,350,364,365,382,384,602,605,610,639,659,660,661,662,695,1016,1028,1029,1030,1031]
science_tagsJ = [1014,313,314,315,323,324,325,326,331,356,357,398,626,633,634,635,636,637,640,641,642,688,1000,1001,1002,1007,1015,1017,1018,1022,1025,1035,1036,1040,1041,1042,1044]
transport_tagsJ = [366,1003,1004,1009,1010,1011,1012]
sports_tagsJ = [623,676]
sante_tagsJ = [351,354,360,369,611,612,613,615,616,663,671,685]
environement_tagsJ = [348,622,674,1008,1024,1027,1033,1034,1045]
education_tagsJ = [304,319,332,333,334,335,336,337,361,370,374,375,630,699,1026,1037,1047,1048]
securite_tagsJ = [654]
entreprise_tagsJ = [306,320,321,322,329,330,338,339,340,341,342,343,344,345,346,347,355,358,378,391,618,624,632,643,644,645,649,657,668,669,675,678,689,690,698,1019]
legislation_tagsJ = [305,308,309,310,311,312,317,318,371,606,646,648,651,653,665,666,670,681,682,691,692,693,694,696,1005,1038,1039,1043]
## Cadrelle 
international_tag = [965,973,977]
france_tag = []
economie_tag= [910,911,979,980,985]
science_tag = [943,202,203,900,907,908,909,913,914,915,917,919,924,929,931,936,937,939,940,957,958,959,960,961,962,963,964,981,983,988,993,997,999]
transport_tag = [934,935,944,945,946,947,948,949,950,956]
sports_tag = []
sante_tag = [972]
environement_tag = [942,932,969,970,971,974,975,986,987,989,990,991,992,994,995]
education_tag = [967,968]
securite_tag = [903,904,905,906,996]
entreprise_tag = [901,916,918,923,933,951,952,982]
legislation_tag= []

international_tag += [249]
france_tag += []
economie_tag += [226,229,300]
science_tag += [219,233,235,236,237,238,240,245,246,247,248,255,256,257,278,279,283,285,290,291,292,295,296,297]
transport_tag += [223]
sports_tag += [234,281]
sante_tag += [217,259]
environement_tag += [275,276,293,298,299]
education_tag += [250]
securite_tag += [210]
entreprise_tag += [209,224,228]
legislation_tag += [200,204,205,260,261,262,263,264,265,26,267,268,269,274,284]
##Jessica nettoyage des tags restant
science_tags_lefts = [7,8,9,12,686,687,734,834,941,47,117,257,258,44,45,47,59,61,67,117,125,128,129,134,207,215,216,244,258,270,362,421,469,475,507,508,520,541,543,563,564]
international_tags_lefts = [85,254,266,773,966]
social_tags_lefts = [10,11,21,22,30,35,39,40,41,42,75,76,78,79,81,92,96,168,169,170,600,601,608,609,614,625,647,652,672,673,697,720,775,879,171,172,173,174,184,185,193,199,231,232,251,252,352,353,372,377,381,386,387,393,394,395,397,417,449,510,523,524,542,575,587,593]
france_tags_lefts = [48,49,50,51,52,53,287,419,476,569,603,810,821]
sante_tags_left = [259,112,222,225,243,253,414,631,750,740,756,830]
securite_tags_left= [86,282,578,584,585]
transport_tags_leftfs = [95,94,95,100,535]
economie_tags_lefts = [985,980,979,118,37,109,114,118,137,242,629]
entreprise_tags_lefts = [15,24,29,99,121,122,144,148,150,154,163,218,230,241,389,424,425,432,445,447,486,495,544,545,573,579,647,656,680,736,738,757,760,795,786,793,802,807,885,886,976]
environnement_tags_lefts = [18,32,33,34,43,132,133,175,176,177,550,552,571,588]
legislation_tags_left = [46,98,155,157,271,273,280,368,380,410,415,463,502,503,504,546,547,548,560,565,577]

## All Tags
import itertools
liste_all_tags = list(itertools.chain(international_tags,france_tags,economie_tags,science_tags,transport_tags,sports_tags,sante_tags,environement_tags,education_tags,securite_tags,entreprise_tags,legislation_tags))
liste_all_tags.extend(list(itertools.chain(international_tagsJ,france_tagsJ,economie_tagsJ,science_tagsJ,transport_tagsJ,sports_tagsJ,sante_tagsJ,environement_tagsJ,education_tagsJ,securite_tagsJ,entreprise_tagsJ,legislation_tagsJ)))
liste_all_tags.extend(list(itertools.chain(internationalG,franceG,economieG,scienceG,transportG,sportsG,santeG,environementG,educationG,securiteG,entrepriseG,legislationG)))
liste_all_tags.extend(list(itertools.chain(international_tag,france_tag,economie_tag,science_tag,transport_tag,sports_tag,sante_tag,environement_tag,education_tag,securite_tag,entreprise_tag,legislation_tag)))
liste_all_tags.extend(list(itertools.chain(science_tags_lefts,international_tags_lefts,france_tags_lefts,sante_tags_left,sante_tags_left,securite_tags_left,transport_tags_leftfs,economie_tags_lefts,environnement_tags_lefts,legislation_tags_left)))

## All labels
international_tags = list(itertools.chain(international_tags,internationalG,international_tagsJ,international_tag,international_tags_lefts))
france_tags = list(itertools.chain(france_tags,franceG,france_tagsJ,france_tag,france_tags_lefts))
economie_tags =list(itertools.chain(economie_tags,economieG,economie_tagsJ,economie_tag,economie_tags_lefts))
science_tags = list(itertools.chain(science_tags,scienceG,science_tagsJ,science_tag,science_tags_lefts))
transport_tags = list(itertools.chain(transport_tags,transportG,transport_tagsJ,transport_tag,transport_tags_leftfs))
sports_tags = list(itertools.chain(sports_tags,sportsG,sports_tagsJ,sports_tag))
sante_tags= list(itertools.chain(sante_tags,santeG,sante_tagsJ,sante_tag,sante_tags_left))
environement_tags = list(itertools.chain(environement_tags,environementG,environement_tagsJ,environement_tag,environnement_tags_lefts))
securite_tags = list(itertools.chain(securite_tags,securiteG,securite_tagsJ,securite_tag,securite_tags_left))
entreprise_tags = list(itertools.chain(entreprise_tags,entrepriseG,entreprise_tagsJ,entreprise_tag,entreprise_tags_lefts))
legislation_tags = list(itertools.chain(legislation_tags,legislationG,legislation_tagsJ,legislation_tag,legislation_tags_left))
education_tags=  list(itertools.chain(education_tags,educationG,education_tagsJ,education_tag))


international.add(international_tags,list(set_of_tags))
france.add(france_tags,list(set_of_tags))
economie.add(economie_tags,list(set_of_tags))
numerique.add(science_tags,list(set_of_tags))
transport.add(transport_tags,list(set_of_tags))
sports.add(sports_tags,list(set_of_tags))
sante.add(sante_tags,list(set_of_tags))
environement.add(environement_tags,list(set_of_tags))
education.add(education_tags,list(set_of_tags))
securite.add(securite_tags,list(set_of_tags))
entreprise.add(entreprise_tags,list(set_of_tags))
legislation.add(legislation_tags,list(set_of_tags))
## Left Tags
set_of_tags_left=set_of_tags.copy()
for i in list(set(liste_all_tags)):
  set_of_tags_left.remove(set_of_tags[i])

print(len(set_of_tags_left)) ## tags left

#print(set_of_tags_left) ## tags left

a,b=international[0],international[1]
for i in range(len(a)):
  print(a[i],b[a[i]])


# ? == pas sur, ! == erreur
#international: c est bon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-313b8df1a47d> in <module>()
#       1
# ----> 2 international = my_list()
#       3 france = my_list()
#       4 economie = my_list()
#       5 numerique = my_list()
#
# NameError: name 'my_list' is not defined

# %%
a,b=france[0],france[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#france:747 -> economique, 996->violence -> en securite
# Out:
# 115 bordeaux
# 568 lyon
# 811 région pays de la loire
# 770 relations bilatérales france
# 604 montpellier
# 607 mulhouse
# 620 nantes
# 621 nationalité francaise
# 627 nice
# 658 outre-mer
# 664 paris
# 677 pays de la loire

# %%
a,b=economie[0],economie[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#economie: 25 26 27 28 administration ?? , 727 production agricole? a supprimer ,382 expertise?,384=0? RESOLU: en fait les 2 strings sont differents et la diff est une espace,
# 202 et 203 conso. elec = tech, entre 219 et 297 FAUX
# Out:
# 0  experts-comptables
# 14 achat
# 23 actualités financières
# 82 assurances
# 101 banque
# 102 banque - finance
# 119 budget de l'etat
# 120 budget européen
# 145 chaîne comptable
# 151 chômage
# 178 commerce
# 186 comptabilité
# 519 investissement
# 583 marché financier
# 853 silver economie
# 854 silvereconomie
# 404 finance & fiscalité
# 405 financement
# 406 financement des partis politiques
# 407 finances
# 408 finances locales
# 409 finances publiques
# 723 prestation sociale
# 725 prix
# 779 ressources
# 783 retraite
# 784 revenu
# 747 prélèvement obligatoire
# 300 economie
# 301 economie internationale
# 302 economie numérique
# 303 economie sociale
# 349 epargne
# 350 epargne salariale
# 364 ess
# 365 essaimage
# 382 expertise
# 384 experts-comptables
# 602 monnaie
# 605 monétique
# 610 mutuelle
# 639 ocde
# 659 paie
# 660 paie & ressources humaines
# 661 paiement
# 662 paiement sans contact
# 695 politique budgétaire
# 1016 wef
# 1028 économie
# 1029 économie circulaire
# ...

# %%
a,b=numerique[0],numerique[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#numerique: 6=date et pas importante, 474=idee?,357 erp?, 1000 1001 1002 entreprise?,900 entreprise?,1000 doublon
#reste a verifier 900
# Out:
# 54 anti-virus
# 55 ap connect
# 56 app mobile
# 60 application mobile
# 77 assistant digital
# 88 automobile
# 89 automobiles
# 104 bas débit
# 105 base de données
# 107 big data
# 108 bigdata
# 113 bitcoin
# 160 cité de l'objet connecté
# 161 civictech
# 166 cloud
# 167 cluster
# 180 commerce électronique
# 197 connecté
# 196 connected week
# 198 connexions
# 506 intelligence
# 509 intelligence artificielle. voix
# 514 internet
# 515 internet des objets
# 527 journal du net
# 539 laboratoire
# 590 messagerie
# 814 rénovation énergétique
# 816 réseau
# 818 réseau électrique
# 819 réseaux
# 820 réseaux bas débit
# 836 sciences
# 837 sciences - numérique - i. a.
# 849 services en ligne
# 860 smart building
# 862 smart cityn développement durable
# 863 smart cité
# 864 smart data
# 865 smart grid
# 866 smart industrie
# 867 smart lightning
# 868 smart mobility
# 867 smart lightning
# 868 smart mobility
# 869 smart parking
# 870 smart village
# 871 smart waste management
# ...

# %%
a,b=transport[0],transport[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#transport: 875 smartphone tech,1014 plutot un app donc tech?
# Out:
# 366 esyl
# 1003 voiture
# 1004 voiture autonome
# 1009 véhicule intelligent
# 1010 vélo
# 1011 vélo connecté
# 1012 vélos
# 934 train
# 935 tramway
# 944 transport
# 945 transport aérien
# 946 transport ferroviaire
# 947 transport fluvial
# 948 transport maritime
# 949 transport routier
# 950 transports
# 956 trottinettes
# 223 covoiturage

# %%
a,b=sports[0],sports[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#sports: c bon
# Out:
# 526 jo paris 2024
# 887 sport
# 623 nautisme
# 676 pavic
# 234 cyclistes
# 281 défense

# %%
a,b=sante[0],sante[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#sante:839 plutot legislation, fitness sport ou sante? , 201=consomation pas sante? a enlever
# Out:
# 80 assurance maladie
# 570 lésions cutanées
# 576 maladie
# 828 sanitaire
# 829 santé
# 831 santé connectée
# 832 santé publique
# 882 soin médical
# 457 handicap
# 458 handicapé
# 472 hôpital
# 351 epidémie
# 354 equipement médical
# 360 esanté
# 369 etablissement sanitaire
# 611 médecin
# 612 médecine
# 613 médecins
# 615 médical
# 616 médicament
# 663 pandémie
# 671 patients
# 685 pharmacie
# 972 urgence
# 217 coronavirus
# 259 dossier santé

# %%
a,b=environement[0],environement[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#environement: 136 categorie socioprofess? 161 civictech? les 
#conseil: si on peut separer environement en sousgroupe, il sera plus propre
# Out:
# 4  secteur public
# 106 bibliothèque
# 110 bio
# 111 biodiversité
# 135 catastrophe naturelle
# 136 catégorie socioprofessionnelle
# 139 centre-ville
# 152 cinéma
# 153 circulation
# 156 citoyenneté
# 158 citoyens
# 159 cité
# 161 civictech
# 165 climat
# 182 commune
# 183 commune nouvelle
# 181 communauté
# 182 commune
# 183 commune nouvelle
# 501 insertion sociale
# 522 jardin
# 558 logement social (hlm)
# 567 lycée
# 589 mers et océans
# 817 réseau social
# 858 situation sociale
# 878 social
# 423 futur
# 427 gaspillage
# 434 gestion eau
# 455 habitat
# 456 habitat indigne
# 466 humain
# 467 humaines
# 468 human city
# 479 immobilier
# 489 industrie culturelle
# 716 pollution
# 717 portail citoyen
# 737 projet citoyen
# 739 projets urbains
# 743 protection de l'environnement
# 766 recyclage
# 767 relation citoyens
# 774 religion
# 776 renouvellement urbain
# 778 responsabilitésociétale
# 796 ruralité
# 800 réchauffement
# 348 environnement
# 622 nature
# 674 patrimoine naturel
# ...

# %%
a,b=education[0],education[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#education: 464 ? a enlever, 327 328 684? enfances a enlever , 942 et 943 environement, 955 tribune
# Out:
# 62 apprentissage
# 838 scolarité
# 401 filière électronique
# 416 formation
# 452 guide
# 462 histoire
# 492 infographie
# 493 information
# 722 presse
# 735 programme scolaire
# 751 puériculture
# 304 education - recherche
# 319 elève
# 332 enseignant
# 333 enseignement en alternance
# 334 enseignement primaire
# 335 enseignement professionnel
# 336 enseignement secondaire
# 337 enseignement supérieur
# 361 eseo
# 370 etablissement scolaire
# 374 etudes
# 375 etudiant
# 630 niveau scolaire
# 699 politique de l'enseignement
# 1026 école
# 1037 éducation
# 1047 étude
# 1048 étudiants
# 955 tribune
# 967 université
# 968 universités
# 250 diplôme

# %%
a,b=securite[0],securite[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#securite:protection de donnees et rgpd sont securite ou tech? 744 785
# Out:
# 65 armement
# 66 armée
# 518 intervention militaire
# 592 militaire
# 841 secours
# 897 surveillance
# 430 gendarmerie
# 471 hébergement d'urgence
# 483 incidents
# 724 prison
# 742 protection
# 745 protection du patrimoine
# 788 risque
# 654 otage
# 903 sécurité
# 904 sécurité nucléaire
# 905 sécurité routière
# 906 sécurité sociale
# 996 violence
# 210 controle

# %%
a,b=entreprise[0],entreprise[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#entreprise: 227 creation a supprimer
# Out:
# 5  tpe & auto-entrepreneurs
# 57 appel à projet
# 58 appel à projets
# 192 condition de travail
# 537 la poste
# 549 licenciement
# 582 marché du travail
# 823 salaire
# 824 salariés
# 850 services techniques
# 876 sncf
# 880 société
# 888 start-up
# 889 startup
# 890 startups
# 895 structure d'entreprise
# 429 gazette des communes
# 433 gestion d'entreprise
# 436 gestion rh
# 437 google
# 446 greentech
# 460 hewlett packard
# 500 insertion professionnelle
# 718 pouvoir exécutif
# 729 profession
# 730 profession artistique
# 731 profession judiciaire
# 732 profession libérale
# 733 profession médicale
# 755 qowisio
# 764 reconversion industrielle
# 765 recrutement
# 768 relations administration usager
# 771 relations du travail
# 789 risque professionnel
# 794 ruckus wireless
# 306 egalité professionnelle
# 320 emploi
# 321 emploi - travail
# 322 enedis
# 329 engie
# 330 engie fab
# 338 entrepreneuriat
# 339 entrepreneurs
# 340 entreprise
# 341 entreprise de services
# ...

# %%
a,b=legislation[0],legislation[1]
for i in range(len(a)):
  print(a[i],b[a[i]])
#legislation: c bon
# Out:
# 1  finance & fiscalité
# 2  paie & ressources humaines
# 97 avocats
# 162 civil académie
# 529 juridiction
# 530 juridique
# 531 juristes
# 532 justice
# 533 justice - droits fondamentaux
# 534 justice affaires intérieures
# 559 loi
# 594 ministère
# 804 réforme de l'etat
# 805 réforme territoriale
# 806 réforme électorale
# 813 réglementation
# 826 salon des maires
# 855 simplification administrative
# 857 situation matrimoniale
# 411 fiscalité
# 412 fiscalité locale
# 435 gestion publique
# 439 gouvernance
# 440 gouvernement
# 443 grand public
# 482 impôt
# 700 politique de l'environnement
# 701 politique de l'immigration
# 702 politique de l'énergie
# 703 politique de la défense
# 704 politique de la recherche
# 705 politique de la ville
# 706 politique des transports
# 707 politique européenne de sécurite et de défense
# 708 politique fiscale
# 709 politique gouvernementale
# 710 politique industrielle
# 711 politique judiciaire
# 712 politique monétaire
# 713 politique sociale
# ...

# %% [markdown]
# tags

# %%
## tags
international_tags = [85,254,266,773,966,249,31,36,103,126,147,179,505,513,521,536,540,591,812,815,856,898,420,422,442,451,478,485],754,769,772,787,307,363,373,376,628,650,655,1006,1023,965,973,977]
france_tags =[48,49,50,51,52,53,287,419,476,569,603,810,821,115,568,811,770,604,607,620,621,627,658,664,677]
economie_tags =[985,980,979,118,37,109,114,118,137,242,629,226,229,300,0,14,23,82,101,102,119,120,145,151,178,186,519,583,853,854,404,405,406,407,408,409,723,725,779,783,784,747,300,301,302,303,349,350,364,365,382,384,602,605,610,639,659,660,661,662,695,1016,1028,1029,1030,1031,910,911,979,980,985]
science_tags = [7,8,9,12,686,687,734,834,941,47,117,257,258,44,45,47,59,61,67,117,125,128,129,134,207,215,216,244,258,270,362,421,469,475,507,508,520,541,543,563,564,219,233,235,236,237,238,240,245,246,247,248,255,256,257,278,279,283,285,290,291,292,295,296,297,875,54,55,56,60,77,88,89,104,105,107,108,113,160,161,166,167,180,197,196,198,506,509,514,515,527,539,590,814,816,818,819,820,836,837,849,860,862,863,864,865,866,867,868,867,868,869,870,871,872,873,874,875,894,400,403,418,441,454,459,461,465,470,473,480,481,487,488,490,494,497,499,498,759,761,762,790,791,792,798,799,1014,313,314,315,323,324,325,326,331,356,357,398,626,633,634,635,636,637,640,641,642,688,1000,1001,1002,1007,1015,1017,1018,1022,1025,1035,1036,1040,1041,1042,1044,943,202,203,900,907,908,909,913,914,915,917,919,924,929,931,936,937,939,940,957,958,959,960,961,962,963,964,981,983,988,993,997,999]
transport_tags = [95,94,95,100,535,223,366,1003,1004,1009,1010,1011,1012,934,935,944,945,946,947,948,949,950,956]
sports_tags = [234,281,526,887,413,623,676]
sante_tags= [259,112,222,225,243,253,414,631,750,740,756,830,217,259,972,80,570,576,828,829,831,832,882,457,458,472,351,354,360,369,611,612,613,615,616,663,671,685]
environement_tags = [18,32,33,34,43,132,133,175,176,177,550,552,571,588,275,276,293,298,299,4,106,110,111,135,136,139,152,153,156,158,159,161,165,182,183,181,182,183,501,522,558,567,589,817,858,878,423,427,434,455,456,466,467,468,479,489,716,717,737,739,743,766,767,774,776,778,796,800,348,622,674,1008,1024,1027,1033,1034,1045,942,932,969,970,971,974,975,986,987,989,990,991,992,994,995]
education_tags = [250,967,968,62,838,401,416,452,462,492,493,722,735,751,304,319,332,333,334,335,336,337,361,370,374,375,630,699,1026,1037,1047,1048]
securite_tags = [86,282,578,584,585,210,903,904,905,906,996,65,66,518,592,841,897,430,471,483,724,742,745,788,654]
entreprise_tags = [15,24,29,99,121,122,144,148,150,154,163,218,230,241,389,424,425,432,445,447,486,495,544,545,573,579,647,656,680,736,738,757,760,795,786,793,802,807,885,886,976,209,224,228,901,916,918,923,933,951,952,982,5,57,58,192,537,549,582,823,824,850,876,880,888,889,890,895,429,433,436,437,446,460,500,718,729,730,731,732,733,755,764,765,768,771,789,794,306,320,321,322,329,330,338,339,340,341,342,343,344,345,346,347,355,358,378,391,618,624,632,643,644,645,649,657,668,669,675,678,689,690,698,1019]
legislation_tags = [46,98,155,157,271,273,280,368,380,410,415,463,502,503,504,546,547,548,560,565,577,200,204,205,260,261,262,263,264,265,26,267,268,269,274,284,839,1,2,97,162,529,530,531,532,533,534,559,594,804,805,806,813,826,855,857,411,412,435,439,440,443,482,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,719,721,726,741,746,748,749,797[411,412,435,439,440,443,482,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,719,721,726,741,746,748,749,797,305,308,309,310,311,312,317,318,371,606,646,648,651,653,665,666,670,681,682,691,692,693,694,696,1005,1038,1039,1043]

##tags restant possible a utiliser apres
social_tags_lefts = [10,11,21,22,30,35,39,40,41,42,75,76,78,79,81,92,96,168,169,170,600,601,608,609,614,625,647,652,672,673,697,720,775,879,171,172,173,174,184,185,193,199,231,232,251,252,352,353,372,377,381,386,387,393,394,395,397,417,449,510,523,524,542,575,587,593]

# %%
tags=[1,2]
international=[1,2,3]
france=[4,5,6]
economie=[7,8,9]
science=[10,11,12]
transport=[13,14,15]
sports=[16,17,18]
sante=[19,20,21]
environement=[22,23,24]
education=[25,26,27]
securite=[28,29,30]
entreprise=[31,32,33]
legislation=[34,35,36]
def verif_tag(tag):
  return tag in france or tag in economie or tag in science or tag in transport or tag in sports or tag in sante or tag in environement or tag in education or tag in securite or tag in entreprise or tag in legislation
# Out:
# {'international': 1}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-baa36ed7c563> in <module>()
#      79 a=get_labels(tags,international,france,economie,science,transport,sports,sante,environement,education,securite,entreprise,legislation)
#      80 print(a)
# ---> 81 print(str(sport))
#
# NameError: name 'sport' is not defined
